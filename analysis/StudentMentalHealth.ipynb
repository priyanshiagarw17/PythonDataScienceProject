# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\user\OneDrive\Desktop\Student Mental health.csv')

# %%
print(df)
# Out:
#             Timestamp Choose your gender   Age What is your course?  \
# 0    08-07-2020 12:02             Female  18.0          Engineering
# 1    08-07-2020 12:04               Male  21.0    Islamic education
# 2    08-07-2020 12:05               Male  19.0                  BIT
# 3    08-07-2020 12:06             Female  22.0                 Laws
# 4    08-07-2020 12:13               Male  23.0         Mathemathics
# ..                ...                ...   ...                  ...
# 96   13-07-2020 19:56             Female  21.0                  BCS
# 97   13-07-2020 21:21               Male  18.0          Engineering
# 98   13-07-2020 21:22             Female  19.0             Nursing
# 99   13-07-2020 21:23             Female  23.0     Pendidikan Islam
# 100  18-07-2020 20:16               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 0                       year 1        3.00 - 3.49             No
# ...

# %%
df.head()
# Out:
#           Timestamp Choose your gender   Age What is your course?  \
# 0  08-07-2020 12:02             Female  18.0          Engineering
# 1  08-07-2020 12:04               Male  21.0    Islamic education
# 2  08-07-2020 12:05               Male  19.0                  BIT
# 3  08-07-2020 12:06             Female  22.0                 Laws
# 4  08-07-2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
df.tail()
# Out:
#             Timestamp Choose your gender   Age What is your course?  \
# 96   13-07-2020 19:56             Female  21.0                  BCS
# 97   13-07-2020 21:21               Male  18.0          Engineering
# 98   13-07-2020 21:22             Female  19.0             Nursing
# 99   13-07-2020 21:23             Female  23.0     Pendidikan Islam
# 100  18-07-2020 20:16               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 96                      year 1        3.50 - 4.00             No
# 97                      Year 2        3.00 - 3.49             No
# 98                      Year 3        3.50 - 4.00            Yes
# 99                      year 4        3.50 - 4.00             No
# 100                     Year 2        3.00 - 3.49             No
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 96                       No                  Yes                        No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Timestamp                                     101 non-null    object
#  1   Choose your gender                            101 non-null    object
#  2   Age                                           100 non-null    float64
#  3   What is your course?                          101 non-null    object
#  4   Your current year of Study                    101 non-null    object
#  5   What is your CGPA?                            101 non-null    object
#  6   Marital status                                101 non-null    object
#  7   Do you have Depression?                       101 non-null    object
#  8   Do you have Anxiety?                          101 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             1
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %%
df.loc[df["Do you have Depression?"] == "Yes", "Do you have Depression?"] = 1
df.loc[df["Do you have Depression?"] == "No", "Do you have Depression?"] = 0
df.sample(10)
# Out:
#            Timestamp Choose your gender   Age What is your course?  \
# 13  08-07-2020 12:41               Male  19.0          Engineering
# 82  13-07-2020 10:12             Female  19.0          Engineering
# 23  08-07-2020 13:15             Female  24.0          Engineering
# 57  08-07-2020 16:21             Female  20.0                 BENL
# 61  08-07-2020 16:53             Female  19.0                  BCS
# 14  08-07-2020 12:43             Female  18.0                KENMS
# 12  08-07-2020 12:40             Female  18.0                  BCS
# 95  13-07-2020 19:08             Female  18.0    Islamic Education
# 21  08-07-2020 13:13             Female  18.0                  KOE
# 56  08-07-2020 16:08               Male  23.0               Kirkhs
#
#    Your current year of Study What is your CGPA? Marital status  \
# 13                     year 1        3.00 - 3.49             No
# 82                     year 1        3.00 - 3.49             No
# ...

# %%
df.loc[df["Do you have Anxiety?"] == "Yes", "Do you have Anxiety?"] = 1
df.loc[df["Do you have Anxiety?"] == "No", "Do you have Anxiety?"] = 0
df.sample(10)
# Out:
#            Timestamp Choose your gender   Age What is your course?  \
# 7   08-07-2020 12:33             Female  18.0                  BCS
# 70  08-07-2020 20:36             Female  24.0   Biomedical science
# 83  13-07-2020 10:12             Female  19.0    Pendidikan Islam
# 47  08-07-2020 15:14             Female  18.0               Engine
# 33  08-07-2020 14:31               Male  18.0                  BCS
# 67  08-07-2020 18:11               Male  19.0                 MHSC
# 56  08-07-2020 16:08               Male  23.0               Kirkhs
# 29  08-07-2020 14:05             Female  24.0                  BCS
# 21  08-07-2020 13:13             Female  18.0                  KOE
# 3   08-07-2020 12:06             Female  22.0                 Laws
#
#    Your current year of Study What is your CGPA? Marital status  \
# 7                      year 1        3.50 - 4.00             No
# 70                     year 1        3.00 - 3.49             No
# ...

# %%
df.loc[df["Do you have Panic attack?"] == "Yes", "Do you have Panic attack?"] = 1
df.loc[df["Do you have Panic attack?"] == "No", "Do you have Panic attack?"] = 0
df.sample(10)
# Out:
#            Timestamp Choose your gender   Age What is your course?  \
# 73  09-07-2020 06:57               Male  18.0   Biomedical science
# 41  08-07-2020 14:57             Female  22.0          Engineering
# 92  13-07-2020 14:48             Female  19.0                  KOE
# 59  08-07-2020 16:34             Female  23.0                 Benl
# 52  08-07-2020 15:47             Female  19.0   Biomedical science
# 89  13-07-2020 11:54               Male  24.0          Engineering
# 9   08-07-2020 12:39               Male  18.0                Irkhs
# 40  08-07-2020 14:57             Female  24.0                  BIT
# 64  08-07-2020 17:46             Female  24.0               Engine
# 31  08-07-2020 14:29               Male  18.0                  BCS
#
#    Your current year of Study What is your CGPA? Marital status  \
# 73                     year 1           0 - 1.99             No
# 41                     year 4        3.50 - 4.00             No
# ...

# %%
df.loc[df["Did you seek any specialist for a treatment?"] == "Yes", "Did you seek any specialist for a treatment?"] = 1
df.loc[df["Did you seek any specialist for a treatment?"] == "No", "Did you seek any specialist for a treatment?"] = 0
df.sample(5)
# Out:
#            Timestamp Choose your gender   Age What is your course?  \
# 67  08-07-2020 18:11               Male  19.0                 MHSC
# 65  08-07-2020 17:50             Female  23.0                Econs
# 90  13-07-2020 13:57             Female  23.0         DIPLOMA TESL
# 83  13-07-2020 10:12             Female  19.0    Pendidikan Islam
# 29  08-07-2020 14:05             Female  24.0                  BCS
#
#    Your current year of Study What is your CGPA? Marital status  \
# 67                     Year 3        3.00 - 3.49            Yes
# 65                     year 1        3.50 - 4.00             No
# 90                     Year 3        3.50 - 4.00             No
# 83                     Year 2        3.00 - 3.49             No
# 29                     year 4        3.50 - 4.00             No
#
#    Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 67                       1                    0                         1
# ...

# %%
df.loc[df["Marital status"] == "Yes", "Marital status"] = 1
df.loc[df["Marital status"] == "No", "Marital status"] = 0
df.sample(5)
# Out:
#            Timestamp Choose your gender   Age What is your course?  \
# 37  08-07-2020 14:45             Female  19.0                  BIT
# 62  08-07-2020 17:05             Female  18.0                  CTS
# 49  08-07-2020 15:18             Female  24.0                  BCS
# 97  13-07-2020 21:21               Male  18.0          Engineering
# 26  08-07-2020 13:35             Female  19.0          Engineering
#
#    Your current year of Study What is your CGPA? Marital status  \
# 37                     year 1        2.50 - 2.99              0
# 62                     Year 1        3.50 - 4.00              0
# 49                     year 3        3.50 - 4.00              0
# 97                     Year 2        3.00 - 3.49              0
# 26                     year 1        3.50 - 4.00              0
#
#    Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 37                       1                    1                         1
# ...

# %%
df.rename(columns={
    "Do you have Depression?": "Depression",
    "Do you have Anxiety?": "Anxiety",
    "What is your CGPA?": "CGPA",
    "marital status": "MaritalStatus",
    "Do you have Panic attack?" : "Panicattack",
    "Did you seek any specialist for a treatment?" : "Specialist",
    "Choose your gender" : "Gender",
    "What is your course?" : "Course",
    "Your current year of Study" : "Year"
}, inplace=True)

# %%
df
# Out:
#             Timestamp  Gender   Age              Course    Year         CGPA  \
# 0    08-07-2020 12:02  Female  18.0         Engineering  year 1  3.00 - 3.49
# 1    08-07-2020 12:04    Male  21.0   Islamic education  year 2  3.00 - 3.49
# 2    08-07-2020 12:05    Male  19.0                 BIT  Year 1  3.00 - 3.49
# 3    08-07-2020 12:06  Female  22.0                Laws  year 3  3.00 - 3.49
# 4    08-07-2020 12:13    Male  23.0        Mathemathics  year 4  3.00 - 3.49
# ..                ...     ...   ...                 ...     ...          ...
# 96   13-07-2020 19:56  Female  21.0                 BCS  year 1  3.50 - 4.00
# 97   13-07-2020 21:21    Male  18.0         Engineering  Year 2  3.00 - 3.49
# 98   13-07-2020 21:22  Female  19.0            Nursing   Year 3  3.50 - 4.00
# 99   13-07-2020 21:23  Female  23.0    Pendidikan Islam  year 4  3.50 - 4.00
# 100  18-07-2020 20:16    Male  20.0  Biomedical science  Year 2  3.00 - 3.49
#
# ...

# %%
df.drop(columns=["Timestamp"], inplace=True)

# %%
df
# Out:
#      Gender   Age              Course    Year         CGPA Marital status  \
# 0    Female  18.0         Engineering  year 1  3.00 - 3.49              0
# 1      Male  21.0   Islamic education  year 2  3.00 - 3.49              0
# 2      Male  19.0                 BIT  Year 1  3.00 - 3.49              0
# 3    Female  22.0                Laws  year 3  3.00 - 3.49              1
# 4      Male  23.0        Mathemathics  year 4  3.00 - 3.49              0
# ..      ...   ...                 ...     ...          ...            ...
# 96   Female  21.0                 BCS  year 1  3.50 - 4.00              0
# 97     Male  18.0         Engineering  Year 2  3.00 - 3.49              0
# 98   Female  19.0            Nursing   Year 3  3.50 - 4.00              1
# 99   Female  23.0    Pendidikan Islam  year 4  3.50 - 4.00              0
# 100    Male  20.0  Biomedical science  Year 2  3.00 - 3.49              0
#
#     Depression Anxiety Panicattack Specialist
# ...
